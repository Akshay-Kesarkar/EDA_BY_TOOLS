# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\HP\Desktop\Algerian_forest_fires_dataset_UPDATE.csv',header=1)

# %% [markdown]
# ### Sample Of Data

# %%
df.head()
# Out:
#    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29   57   18    0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29   61   13    1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26   82   22   13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25   89   13    2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27   77   16    0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI    Classes    Region
# 0  0.5  not fire          1
# 1  0.4  not fire          1
# 2  0.1  not fire          1
# 3    0  not fire          1
# 4  0.5  not fire          1

# %%
df.tail()
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes    Region
# 239  16.9  6.5       fire          0
# 240   6.2    0   not fire          0
# 241   3.4  0.2   not fire          0
# 242   5.1  0.7   not fire          0
# 243   4.8  0.5  not fire           0

# %% [markdown]
# ### Information of Data
# 1. Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012) </br>
# Weather data observations </br>
# 2. Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42 </br>
# 3. RH : Relative Humidity in %: 21 to 90 </br>
# 4. Ws :Wind speed in km/h: 6 to 29 </br>
# 5. Rain: total day in mm: 0 to 16.8 </br>
# FWI Components </br>
# 6. Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5 </br>
# 7. Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9 </br>
# 8. Drought Code (DC) index from the FWI system: 7 to 220.4 </br>
# 9. Initial Spread Index (ISI) index from the FWI system: 0 to 18.5 </br>
# 10. Buildup Index (BUI) index from the FWI system: 1.1 to 68 </br>
# 11. Fire Weather Index (FWI) Index: 0 to 31.1

# %% [markdown]
# ### Shape of the dataset

# %%
df.shape
# Out:
# (244, 15)

# %% [markdown]
# ### Summary of the dataset

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  244.000000  244.000000   244.0   244.000000  244.000000  244.000000
# mean    15.754098    7.500000  2012.0    32.172131   61.938525   15.504098
# std      8.825059    1.112961     0.0     3.633843   14.884200    2.810178
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%     16.000000    7.500000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.250000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#             Rain         FFMC         DMC         ISI         BUI      Region
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean     0.760656   77.887705   14.673361    4.774180   16.664754    0.500000
# ...

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29   57   18    0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29   61   13    1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26   82   22   13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25   89   13    2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27   77   16    0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...   ...   ...  ...
# 239   26      9  2012           30   65   14    0.0  85.4  16.0  44.5  4.5
# 240   27      9  2012           28   87   15    4.4  41.1   6.5     8  0.1
# 241   28      9  2012           27   87   29    0.5  45.9   3.5   7.9  0.4
# 242   29      9  2012           24   54   18    0.1  79.7   4.3  15.2  1.7
# 243   30      9  2012           24   64   15    0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI     Classes    Region
# ...

# %% [markdown]
# ### Looking For Null Value

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# dtype: int64

# %%
#Check Datatypes in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4    RH          244 non-null    int64
#  5    Ws          244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    int64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 28.7+ KB

# %% [markdown]
# # EXPLORING DATA

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 12 numerical features : ['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC', 'DMC', 'ISI', 'BUI', 'Region']
#
# We have 3 categorical features : ['DC', 'FWI', 'Classes  ']

# %% [markdown]
# ## categorical features information
# Drought Code (DC) index from the FWI system</br>
# Fire Weather Index (FWI) Index</br>
# Classes fire or not fire

# %%
# proportion of count data on categorical columns
for col in categorical_features:
    print(df[col].value_counts(normalize=True) * 100)
    print('---------------------------')
# Out:
# 8        2.049180
# 7.6      1.639344
# 7.8      1.639344
# 8.4      1.639344
# 7.5      1.639344
#            ...
# 90.4     0.409836
# 100.7    0.409836
# 110.9    0.409836
# 120.9    0.409836
# 16.5     0.409836
# Name: DC, Length: 198, dtype: float64
# ---------------------------
# 0.4     4.918033
# 0.8     4.098361
# 0.5     3.688525
# 0.1     3.688525
# 0       3.688525
#           ...
# 30.2    0.409836
# 20.3    0.409836
# 22.3    0.409836
# 20.4    0.409836
# 6.5     0.409836
# Name: FWI, Length: 126, dtype: float64
# ---------------------------
# fire             53.909465
# not fire         41.563786
# fire              1.646091
# fire              0.823045
# not fire          0.823045
# not fire          0.411523
# not fire          0.411523
# not fire          0.411523
# Name: Classes  , dtype: float64
# ---------------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
from six.moves import urllib

warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ## Univariate Analysis
# The term univariate analysis refers to the analysis of one variable prefix “uni” means “one.” The purpose of univariate analysis is to understand the distribution of values for a single variable.

# %% [markdown]
# # Numerical Features

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True, color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %% [markdown]
# ### Observation
# Outliers in Ws,Rain, FFM, DMC, ISI and in BUI </br>
# Cause of of fire climate change

# %%
# categorical columns
plt.figure(figsize=(70, 30))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
cat1 = ['DC', 'FWI', 'Classes  ']
for i in range(0, len(cat1)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[cat1[i]])
    plt.xlabel(cat1[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# #### Multivariate Analysis
# Multivariate analysis is the analysis of more than one variable.

# %% [markdown]
# #### Check Multicollinearity in Numerical features

# %%
df[(list(df.columns)[1:])].corr()
# Out:
#                     month  year  Temperature        RH        Ws     Rain   \
# month        1.000000e+00   NaN    -0.059017 -0.037884 -0.041447  0.035322
# year                  NaN   NaN          NaN       NaN       NaN       NaN
# Temperature -5.901677e-02   NaN     1.000000 -0.654443 -0.278132 -0.326786
#  RH         -3.788419e-02   NaN    -0.654443  1.000000  0.236084  0.222968
#  Ws         -4.144673e-02   NaN    -0.278132  0.236084  1.000000  0.170169
# Rain         3.532207e-02   NaN    -0.326786  0.222968  0.170169  1.000000
# FFMC         1.557668e-02   NaN     0.677491 -0.645658 -0.163255 -0.544045
# DMC          6.817778e-02   NaN     0.483105 -0.405133 -0.001246 -0.288548
# ISI          6.168011e-02   NaN     0.607551 -0.690637  0.015248 -0.347105
# BUI          8.582162e-02   NaN     0.455504 -0.348587  0.029756 -0.299171
# Region       6.718556e-17   NaN    -0.273496  0.406424  0.176829  0.041080
#
#                  FFMC       DMC       ISI       BUI        Region
# ...

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), cmap="CMRmap", annot=True)
plt.show()

# %% [markdown]
# # Check Multicollinearity for Categorical features
# Here we check Temprature corelation with 'DC', 'FWI' and 'Classes '

# %%
from scipy.stats import chi2_contingency
chi2_test = []
for feature in categorical_features:
    if chi2_contingency(pd.crosstab(df['Temperature'], df[feature]))[1] < 0.05:
        chi2_test.append('Reject Null Hypothesis')
    else:
        chi2_test.append('Fail to Reject Null Hypothesis')
result = pd.DataFrame(data=[categorical_features, chi2_test]).T
result.columns = ['Column', 'Hypothesis Result']
result
# Out:
#       Column               Hypothesis Result
# 0         DC          Reject Null Hypothesis
# 1        FWI  Fail to Reject Null Hypothesis
# 2  Classes            Reject Null Hypothesis

# %%
continues_features=[feature for feature in numeric_features if len(df[feature].unique())>=10]
print('Num of continues features :',continues_features)
# Out:
# Num of continues features : ['day', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC', 'DMC', 'ISI', 'BUI']

# %%
fig = plt.figure(figsize=(15, 20))

for i in range(0, len(continues_features)):
    ax = plt.subplot(8, 2, i+1)

    sns.scatterplot(data= df ,x='Temperature', y=continues_features[i], color='b')
    plt.xlim(0,100) 
    plt.tight_layout()

# %% [markdown]
# ## Report
# Temprature was high increase from 20 to 40 and higher

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df.Temperature, bins=10, kde=True, color = 'b')
plt.title("Temprature Distribution", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Temperature", weight="bold", fontsize=12)
plt.xlim(0,100)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df.DMC, bins=50, kde=True, color = 'b')
plt.title("DMC Distribution", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("DMC", weight="bold", fontsize=12)
plt.xlim(0,100)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df.ISI, bins=50, kde=True, color = 'b')
plt.title("ISI Distribution", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("ISI", weight="bold", fontsize=12)
plt.xlim(0,30)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df.BUI, bins=50, kde=True, color = 'b')
plt.title("BUI Distribution", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("BUI", weight="bold", fontsize=12)
plt.xlim(0,100)
plt.show()
